# %% [markdown]
# # Tecnologias e Aplicações - Computação Gráfica
#
#
# Grupo:
#
# * A82202 - Joel Gama
# * A82491 - Tiago Pinheiro
# * A75362 - Vitor Gomes

# %% [markdown]
# ### References
#
# https://www.tensorflow.org/tutorials/load_data/images
#
# https://www.tensorflow.org/api_docs/python/tf/data/Dataset
#
# https://www.youtube.com/watch?v=yH1cF7GnoIo
#
# https://www.datacamp.com/community/tutorials/tensorflow-tutorial

# %%
import tensorflow as tf
from tensorflow import keras
import os
import numpy as np

import matplotlib.pyplot as plt
import pathlib
from PIL import Image
import IPython.display as display

# %% [markdown]
# #### Batch Size usado: 16
#
# Sabendo que o *Batch Size* consegue estabilizar a rede e faz com que ela aprenda a um ritmo mais *ideal*. Para nós antigirmos o valor de 16, fizemos alguns teste usando a mesma rede.
#
# Com o *batch size* 16 obtivémos os melhores resultados, para além dá rede obter uma maior percentagem de precisão nos testes, ela era mais consistente e convergia mais rapidamente do que quando testada com outros valores para o *batch size*.

# %%
BATCH_SIZE = 16
IMAGE_SIZE = 32

# %% [markdown]
# ### Preparação para o carregamento de imagens
#
# Definição da pasta onde se encontram as imagens de treino

# %%
data_dir = pathlib.Path('../gtsrb/train_images/')
signs = list(data_dir.glob('00001/*'))
  
classNames = np.array(os.listdir(data_dir))
classNames
# Out:
# array(['00000', '00001', '00002', '00003', '00004', '00005', '00006',
#        '00007', '00008', '00009', '00010', '00011', '00012', '00013',
#        '00014', '00015', '00016', '00017', '00018', '00019', '00020',
#        '00021', '00022', '00023', '00024', '00025', '00026', '00027',
#        '00028', '00029', '00030', '00031', '00032', '00033', '00034',
#        '00035', '00036', '00037', '00038', '00039', '00040', '00041',
#        '00042'], dtype='<U5')

# %% [markdown]
# ### Funções auxiliares
#
# Definição de funções auxiliares para o carregamento de imagens para um dataset
#
# * get_bytes_and_label(file_path):
#
#     * Recebe um tensor object com um caminho para uma imagem.
#     * Devolve um tensor com a imagem e a sua categoria.
#
# * validacao(file_path,valsplit):
#     * Recebe um tensor com a localização de uma imagem e a fração do dataset de validação.
#     * Devolve um booleano indicando se a imagem deve pertencer ou não ao dataset de validação.

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return parts[-2] == classNames

def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_png(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [32,32])

def get_bytes_and_label(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

def validacao(file_path,valsplit):
    
    parts = tf.strings.split(file_path, os.path.sep)
    seq_num = tf.strings.to_number(tf.strings.split(parts[-1], '_')[0])
    
    return (int(seq_num)%round(1/valsplit)) == 0

# %% [markdown]
# ### Carregamento de imagens
#
# Nesta secção é realizado o carregamento das imagens para os datasets de treino e de validação.
# Visto que o dataset utilizado é constituído por imagens de sequências de vídeo, o carregamento destas para a criação dos datasets de treino e de validação é feito de forma a que imagens pertencentes à mesma sequência de vídeo fiquem no mesmo dataset e assim as redes neuronais não sejam validadas com um dataset parecido com o que treinaram.
#
# A varíavel valsplit define a porção de imagens do dataset a carregar que irá pertencer ao dataset para validação. Pela forma que está implementada a definição destes datasets, o split real será um pouco maior que o definido. Escolheu-se um split para o dataset de validação que foi com o qual se obteve resultados melhores e mais consistentes.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

listset = tf.data.Dataset.list_files("../gtsrb/train_images/*/*.png")

valsplit = 0.2

valset = listset.filter(lambda f: validacao(f,valsplit))
valset = valset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)

trainset = listset.filter(lambda f: not(validacao(f,valsplit)))
trainset = trainset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)

# %% [markdown]
# ### Informação acerca dos datasets criados
#
# Impressão de informação sobre os datasets criados. Isto é, a largura, altura e nº de canais que as suas imagens possuem, assim como o número total de imagens presentes nos datasets.

# %%
for image, label in valset.take(1):
  print("Image shape: ", image.numpy().shape)
  
valset_length = [i for i,_ in enumerate(valset)][-1] + 1
print("Total images in dataset: ",valset_length)

for image, label in trainset.take(1):
  print("Image shape: ", image.numpy().shape)
  
trainset_length = [i for i,_ in enumerate(trainset)][-1] + 1
print("Total images in dataset: ",trainset_length)
# Out:
# Image shape:  (32, 32, 3)
# Total images in dataset:  8340
# Image shape:  (32, 32, 3)
# Total images in dataset:  30869

# %% [markdown]
# ### Função que irá processar as imagens para augmentar o dataset
#
# Esta função será aplicada a cada elemento do dataset para aplicar uma variedade de transformações às imagens com o objetivo de enriquecer o dataset com o mesmo conjunto de imagens.
# Esta função pode aplicar cada uma das seguintes transformações com 20% de probabilidade:
# * Translação e rotação aleatórias
# * Mudança de contraste aleatória
# * Mudança de brilho
# * Aplicação de uma simulação de sombra
# * Aplicação de uma simulação de obstrução
# * Aplicação de ruído sal e pimenta

# %%
import random

#https://www.tensorflow.org/api_docs/python/tf/image
#https://www.tensorflow.org/addons/api_docs/python/tfa/image

#pip install tensorflow-addons
import tensorflow_addons as tfa

@tf.function
def process_image(image, label):
    
    r = tf.random.uniform(shape=(), minval=0, maxval=1)
    
    if r < 0.2:

        image = tf.image.resize(image, (64,64))
        r = tf.random.uniform(shape=(), minval=0, maxval=1)* 0.5 - 0.25
        image = tfa.image.rotate(image, r)

        rx = tf.random.uniform(shape=(), minval=0, maxval=1) * 20 - 10
        ry = tf.random.uniform(shape=(), minval=0, maxval=1) * 8 - 4
        image = tfa.image.translate(image, [rx, ry])

        image = tfa.image.random_hsv_in_yiq(image, 0.3, 0.9, 1.1, 0.9, 1.3)
        image = tf.image.resize(image, (32,32))
    
    r = tf.random.uniform(shape=(), minval=0, maxval=1)
    
    if r < 0.2:
    
        #image = tf.image.random_crop(image, size=[32, 32, 3]) # Random crop back to 28x28
        #image = tf.image.random_brightness(image, max_delta=0.10) # Random brightness
        image = tf.image.random_contrast(image,0.5,2)

    r = tf.random.uniform(shape=(), minval=0, maxval=1)
    
    if r< 0.2:
        image = tf.clip_by_value(tf.image.adjust_brightness(image, tf.random.uniform(shape=(), minval=0, maxval=1)-0.2),0,1)
    
    r = tf.random.uniform(shape=(), minval=0, maxval=1)
    
    if r < 0.2:
        
        a = tf.random.normal(shape=(), mean=0.0, stddev=1, dtype=tf.float32)
        b = tf.random.uniform(shape=(), minval=0, maxval=32) 

        image = tf.image.rgb_to_hsv(image)
        media=0.0
        for ex in imagem:
            for ey in ex:
                media = media+ey[2]
                
        media = media / (32*32)
        bup=1.25
        bdown=0.75
        if media > 0.75:
            bup = 1.0
        elif media <0.25:
            bup=1.0
        
        sombra = tf.TensorArray(tf.float32,size=32)
        #sombra=np.empty((32,32,3))
        x = tf.constant(0)
        while x < 32:
            sombray = tf.TensorArray(tf.float32,size=32)
            y = tf.constant(0)
            reta = tf.cast(a*tf.cast((x-16),tf.float32)+b,tf.int32)
            while y < 32:
                if reta < y:
                    sombray = sombray.write(y,[1,1,bdown])
                    #sombra[tf.math.floordiv(x,32),tf.math.floormod(x,32)] = [0,0,0.2]
                else:
                    sombray = sombray.write(y,[1,1,bup])
                    #sombra[tf.math.floordiv(x,32),tf.math.floormod(x,32)] = [0,0,-0.2]
                y+=1
            sombra = sombra.write(x,sombray.stack())
            x += 1


        image = image * sombra.stack()

        image = tf.image.hsv_to_rgb(image)
    if r < 0.2:
        
        
        r = tf.random.uniform(shape=(), minval=0, maxval=1, dtype=tf.float32)
        g = tf.random.uniform(shape=(), minval=0, maxval=1, dtype=tf.float32)
        b = tf.random.uniform(shape=(), minval=0, maxval=1, dtype=tf.float32)
        x1 = tf.random.uniform(shape=(), minval=0, maxval=24, dtype=tf.int32) 
        y1 = tf.random.uniform(shape=(), minval=0, maxval=24, dtype=tf.int32) 
        dx = tf.random.uniform(shape=(), minval=6, maxval=12, dtype=tf.int32) 
        dy = tf.random.uniform(shape=(), minval=6, maxval=12, dtype=tf.int32) 

        
        sombra = tf.TensorArray(tf.float32,size=32)
        obs = tf.TensorArray(tf.float32,size=32)
        #sombra=np.empty((32,32,3))
        x = tf.constant(0)
        while x < 32:
            sombray = tf.TensorArray(tf.float32,size=32)
            obsy = tf.TensorArray(tf.float32,size=32)
            y = tf.constant(0)
            x_space = x1 <= x and x1+dx>x
            while y < 32:
                if x_space and y1 <= y and y1+dy >y:
                    sombray = sombray.write(y,[0,0,0])
                    obsy = obsy.write(y,[r,g,b])
                else:
                    sombray = sombray.write(y,[1,1,1])
                    obsy = obsy.write(y,[0,0,0])
                y+=1
            sombra = sombra.write(x,sombray.stack())
            obs = obs.write(x,obsy.stack())
            x += 1


        image = image * sombra.stack() + obs.stack()

    
    r = tf.random.uniform(shape=(), minval=0, maxval=1)
    if r < 0.2:
        
        samples = tf.random.poisson([32,32,3], 0.005)
        image=image-samples
        samples = tf.random.poisson([32,32,3], 0.005)
        image = image + samples
   
     
    image = tf.clip_by_value(image, 0.0, 1.0)
    
    return image, label
# Out:
# '\n\ndef process_image(image, label):\n    \n    r = tf.random.uniform(shape=(), minval=0, maxval=1)\n    \n    sombra=np.empty((32,32,3))\n    a = tf.random.normal(shape=tf.shape(image), mean=0.0, stddev=1, dtype=tf.float32)\n    b = tf.random.uniform(shape=(), minval=0, maxval=32) \n    \n    if r < 0.2:\n\n    \n        image = tf.image.resize(image, (64,64))\n        r = tf.random.uniform(shape=(), minval=0, maxval=1)* 0.5 - 0.25\n        image = tfa.image.rotate(image, r)\n\n        rx = tf.random.uniform(shape=(), minval=0, maxval=1) * 20 - 10\n        ry = tf.random.uniform(shape=(), minval=0, maxval=1) * 8 - 4\n        image = tfa.image.translate(image, [rx, ry])\n        f = r < 0\n        image = tfa.image.random_hsv_in_yiq(image, 0.3, 0.9, 1.1, 0.9, 1.3)\n        image = tf.image.resize(image, (32,32))\n        for x,ex in enumerate(sombra):\n            for y,ey in enumerate(ex):\n                sombra[x,y] = [1,0,1]\n                if x+y<32 and y>16:\n                    sombra[x,y] = [0,0,-0.2]\n                elif not x+y<32 and y>16:\n                    sombra[x,y] = [0,0,0.2]\n                else:\n                    sombra[x,y] = [0,0,0]\n    elif r < 0.4:\n    \n        #image = tf.image.random_crop(image, size=[32, 32, 3]) # Random crop back to 28x28\n        #image = tf.image.random_brightness(image, max_delta=0.10) # Random brightness\n        image = tf.image.random_contrast(image,0.5,2)\n        f = r < 0\n        for x,ex in enumerate(sombra):\n            for y,ey in enumerate(ex):\n                sombra[x,y] = [1,0,1]\n                if x<y and y<b:\n                    sombra[x,y] = [0,0,-0.2]\n                elif not x<y and y<b:\n                    sombra[x,y] = [0,0,0.2]\n                else:\n                    sombra[x,y] = [0.5,0,1]\n    elif r< 0.6:\n        image = tf.clip_by_value(tf.image.adjust_brightness(image, tf.random.uniform(shape=(), minval=0, maxval=1)-0.2),0,1)\n        f = r < 0\n        for x,ex in enumerate(sombra):\n            for y,ey in enumerate(ex):\n                sombra[x,y] = [1,0,1]\n                if x<y:\n                    sombra[x,y] = [0,0,-0.2]\n                elif not x<y:\n                    sombra[x,y] = [0,0,0.2]\n                else:\n                    sombra[x,y] = [0,0,1]\n    elif r < 0.8:\n        samples = tf.random.poisson([32,32,3], 0.005)\n        image=image-samples\n        samples = tf.random.poisson([32,32,3], 0.005)\n        image = image + samples\n    \n        f = r < 0\n        for x,ex in enumerate(sombra):\n            for y,ey in enumerate(ex):\n                sombra[x,y] = [1,0,1]\n                if x+y<32:\n                    sombra[x,y] = [0,0,-0.2]\n                elif not x+y<32:\n                    sombra[x,y] = [0,0,0.2]\n                else:\n                    sombra[x,y] = [0,0,1]\n\n    else:\n    \n        f = r < 0\n        for x,ex in enumerate(sombra):\n            for y,ey in enumerate(ex):\n                s=x+y\n                valor = tf.cond(tf.cast(s<16,tf.bool),lambda: 0.2,lambda: -0.2)\n                sombra[x,y] = [0,0,valor]\n\n    image = tf.clip_by_value(image, 0.0, 1.0)\n\n    \n    image = tf.image.rgb_to_hsv(image)\n    \n    \n    image = image + sombra\n    image = tf.image.hsv_to_rgb(image)\n    \n    \n    return image, label\n \n'

# %% [markdown]
# ### Preparação dos datasets
#
# Shuffle dos datasets para tornar a sua ordem aleatória

# %%
    valset = valset.cache()
    valset = valset.shuffle(buffer_size = valset_length)
    valset = valset.map(process_image, num_parallel_calls=AUTOTUNE)
    valset = valset.batch(batch_size=BATCH_SIZE)
    valset = valset.prefetch(buffer_size=AUTOTUNE)
    valset = valset.repeat()

    trainset = trainset.cache()
    trainset = trainset.shuffle(buffer_size = trainset_length)
    trainset = trainset.map(process_image, num_parallel_calls=AUTOTUNE)
    trainset = trainset.batch(batch_size=BATCH_SIZE)
    trainset = trainset.prefetch(buffer_size=AUTOTUNE)
    trainset = trainset.repeat()

# %% [markdown]
# ### Carregamento e preparação do dataset de teste

# %%
testSplit = 0.8

testset = tf.data.Dataset.list_files("../gtsrb/test_images/*/*.png")
print(testset)
testset = testset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)
testset = testset.batch(batch_size=BATCH_SIZE)
# Out:
# <ShuffleDataset shapes: (), types: tf.string>

# %% [markdown]
# ### Visualização de um batch de imagens de treino

# %%
def show_batch(image_batch, label_batch):
  columns = 6
  rows = BATCH_SIZE / columns + 1  
  plt.figure(figsize=(10, 2 * rows))
  for n in range(BATCH_SIZE):
      ax = plt.subplot(rows, columns, n+1)
      plt.imshow((image_batch[n]))
      plt.title(classNames[label_batch[n]==1][0])
      plt.axis('off')
        
        
image_batch, label_batch = next(iter(trainset))        
show_batch(image_batch, label_batch.numpy())

# %% [markdown]
# ### Construção de rede neuronal
#
#
# Optou-se por usar uma rede neuronal convolucional por serem as mais aconselhadas para reconhecimento e classificação de imagens. Estas costumam começar com um número reduzido de filtros a aplicar que vai aumentando, razão pela qual se optou por aplicar 2 convoluções com 32 filtros seguidas de 2 convoluções com 128 filtros. As funções de ativação *relu* foram as que forneceram melhores resultados e por isso optou-se por estas.
#
# O algoritmo Adam foi utilizado como otimizador com uma taxa de aprendizagem de 0.001 que foi com o qual se obteve resultados melhores e uma convergência mais rápida.
#
# O Max-Pooling aplicado ajuda a generalizar características encontradas nas imagens combatendo o over-fitting. A aplicação desta camada reduz também o número de parâmetros e o consequente tempo de computação.
#
# No final desta rede neuronal existem 2 camadas fully connected. A primeira envolve 256 nodos e a segunda 43 nodos que representam o total de classificações possíveis e é output da rede neuronal.
#
# Quanto ao *Batch Normalization*, ele normaliza os valores da média e variância de cada *batch*, previndo um problema chamado *internal covariate shift*. Isto faz com que a rede convirja muito mais rapidamente, permitindo velocidades de aprendizagem mais altas. E, para além de, obter melhores resultados torna mais funções de activação viáveis. Desta forma, depois de começarmos a utilizar o *batch normalization* tivemos um aumento (significativo) nos nossos valores de aprendizagem.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D,GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras import metrics
from tensorflow.keras.optimizers import Adam, Adadelta

def cnn55D3L2FC(classCount, imgSize, channels):
    model = Sequential()
    
    model.add(Conv2D(32, (3, 3), padding='same',
                     input_shape=(imgSize, imgSize, channels),
                     activation='relu'))                     
    model.add(Conv2D(32, (3, 3), activation='relu') ) 
    model.add(MaxPooling2D(pool_size=(2, 2)))    
    model.add(Dropout(0.2))
    model.add(Conv2D(128, (3, 3), activation='relu') )   
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))
    model.add(Conv2D(128, (3, 3), activation='relu') )   
    model.add(MaxPooling2D(pool_size=(2, 2)))
    
    model.add(Dropout(0.3))
 
    
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.4))
    #model.add(Dense(64, activation='relu'))
    #model.add(Dropout(0.4))
    #model.add(Dense(128, activation='relu'))
    #model.add(Dropout(0.4))

    #model.add(GlobalAveragePoolingD())
    
    model.add(Dense(classCount, activation='softmax'))

 
    
    opt = Adam(lr=0.001)
    #opt = Adadelta(lr=1)
    model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=[ metrics.categorical_accuracy])
    return model

models = []

models.append(cnn55D3L2FC(43, IMAGE_SIZE, 3))
models.append(cnn55D3L2FC(43, IMAGE_SIZE, 3))
models.append(cnn55D3L2FC(43, IMAGE_SIZE, 3))
models.append(cnn55D3L2FC(43, IMAGE_SIZE, 3))
models.append(cnn55D3L2FC(43, IMAGE_SIZE, 3))

# %% [markdown]
# ### Draw a diagram of the network
#
# This requires installing some packages, namely graphviz

# %%
tf.keras.utils.plot_model(models[0], 'multi_input_and_output_model.png', show_shapes=True)

# %% [markdown]
# ### Display a table with model information
#
# When building a model kee an eye on the number of trainable parameters. Try to keep it below 10 million

# %%
print(models[0].summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 13, 13, 128)       36992
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# batch_normalization (BatchNo (None, 256)               1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 43)                11051
# =================================================================
# Total params: 338,123
# Trainable params: 337,611
# Non-trainable params: 512
# _________________________________________________________________
# None

# %% [markdown]
# ### Treino da rede neuronal
#
# Nesta secção é efetuado o treino da rede neuronal.
#
# Nesta secção foram feitos testes com alterações dos seguintes parâmetros:
#
# * `epocas` - Número de épocas a treinar
# * `save` - Define se os resultados das diferentes épocas devem ser guardados
# * `saveBestOnly` - Define se deve ser guardado apenas o resultado da melhor época
#
# O melhor desempenho das redes neuronais treinadas foram obtidos com a gravação de apenas os melhores resultados.
# O nº de épocas foi definido para 20, que é o número de épocas a partir da qual se deixaram de ver melhorias significativas nos resultados dos testes das redes neuronais. A evolucão da accuracy e da loss da rede treinada para 200 iterações pode ser observada nas seguintes imagens.
#
# ![Accuracy](img/200-accu.png)
# ![Loss](img/200-loss.png)
#
# Destas imagens podemos inferir que não haverá grandes vantagens em treinar esta rede por mais de 20 épocas.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint


epocas = 20
save = True

if save:

    if not os.path.exists("checkpoints"):
        os.mkdir("checkpoints")
    
    saveBestOnly=True
    
    checkpointers = []

    checkpointers.append(ModelCheckpoint(filepath="checkpoints/best_weights0-{epoch:03d}.hdf5", 
                                   monitor = 'val_categorical_accuracy',
                                   verbose=1, 
                                   save_best_only=saveBestOnly))

    checkpointers.append(ModelCheckpoint(filepath="checkpoints/best_weights1-{epoch:03d}.hdf5", 
                                   monitor = 'val_categorical_accuracy',
                                   verbose=1, 
                                   save_best_only=saveBestOnly))

    checkpointers.append(ModelCheckpoint(filepath="checkpoints/best_weights2-{epoch:03d}.hdf5", 
                                   monitor = 'val_categorical_accuracy',
                                   verbose=1, 
                                   save_best_only=saveBestOnly))

    checkpointers.append(ModelCheckpoint(filepath="checkpoints/best_weights3-{epoch:03d}.hdf5", 
                                   monitor = 'val_categorical_accuracy',
                                   verbose=1, 
                                   save_best_only=saveBestOnly))

    checkpointers.append(ModelCheckpoint(filepath="checkpoints/best_weights4-{epoch:03d}.hdf5", 
                                   monitor = 'val_categorical_accuracy',
                                   verbose=1, 
                                   save_best_only=saveBestOnly))


    history=[]

    history.append(models[0].fit(trainset, steps_per_epoch = trainset_length/BATCH_SIZE,
              epochs=epocas, validation_data = valset, validation_steps= valset_length/BATCH_SIZE, callbacks=[checkpointers[0]]))

    print(models[0].evaluate(testset))


    history.append(models[1].fit(trainset, steps_per_epoch = trainset_length/BATCH_SIZE,
              epochs=epocas, validation_data = valset, validation_steps= valset_length/BATCH_SIZE, callbacks=[checkpointers[1]]))
    print(models[1].evaluate(testset))


    history.append(models[2].fit(trainset, steps_per_epoch = trainset_length/BATCH_SIZE,
              epochs=epocas, validation_data = valset, validation_steps= valset_length/BATCH_SIZE, callbacks=[checkpointers[2]]))
    print(models[2].evaluate(testset))


    history.append(models[3].fit(trainset, steps_per_epoch = trainset_length/BATCH_SIZE,
              epochs=epocas, validation_data = valset, validation_steps= valset_length/BATCH_SIZE, callbacks=[checkpointers[3]]))
    print(models[3].evaluate(testset))

    history.append(models[4].fit(trainset, steps_per_epoch = trainset_length/BATCH_SIZE,
              epochs=epocas, validation_data = valset, validation_steps= valset_length/BATCH_SIZE, callbacks=[checkpointers[4]]))
    print(models[4].evaluate(testset))
else:
    
    history=[]

    history.append(models[0].fit(trainset, steps_per_epoch = trainset_length/BATCH_SIZE,
              epochs=epocas, validation_data = valset, validation_steps= valset_length/BATCH_SIZE))

    print(models[0].evaluate(testset))


    history.append(models[1].fit(trainset, steps_per_epoch = trainset_length/BATCH_SIZE,
              epochs=epocas, validation_data = valset, validation_steps= valset_length/BATCH_SIZE))
    print(models[1].evaluate(testset))


    history.append(models[2].fit(trainset, steps_per_epoch = trainset_length/BATCH_SIZE,
              epochs=epocas, validation_data = valset, validation_steps= valset_length/BATCH_SIZE))
    print(models[2].evaluate(testset))


    history.append(models[3].fit(trainset, steps_per_epoch = trainset_length/BATCH_SIZE,
              epochs=epocas, validation_data = valset, validation_steps= valset_length/BATCH_SIZE))
    print(models[3].evaluate(testset))

    history.append(models[4].fit(trainset, steps_per_epoch = trainset_length/BATCH_SIZE,
              epochs=epocas, validation_data = valset, validation_steps= valset_length/BATCH_SIZE))
    print(models[4].evaluate(testset))
# Out:
# Train for 1929.3125 steps, validate for 521.25 steps
# Epoch 1/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 1.9009 - categorical_accuracy: 0.4687
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.76811, saving model to checkpoints/best_weights0-001.hdf5
# 1930/1929 [==============================] - 181s 94ms/step - loss: 1.9009 - categorical_accuracy: 0.4688 - val_loss: 0.8090 - val_categorical_accuracy: 0.7681
# Epoch 2/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.8184 - categorical_accuracy: 0.7583 ETA: 1s - loss: 0.8221 - categorical_ac
# Epoch 00002: val_categorical_accuracy improved from 0.76811 to 0.85336, saving model to checkpoints/best_weights0-002.hdf5
# 1930/1929 [==============================] - 174s 90ms/step - loss: 0.8187 - categorical_accuracy: 0.7583 - val_loss: 0.4922 - val_categorical_accuracy: 0.8534
# Epoch 3/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.6232 - categorical_accuracy: 0.8203
# Epoch 00003: val_categorical_accuracy improved from 0.85336 to 0.89269, saving model to checkpoints/best_weights0-003.hdf5
# 1930/1929 [==============================] - 220s 114ms/step - loss: 0.6230 - categorical_accuracy: 0.8204 - val_loss: 0.3782 - val_categorical_accuracy: 0.8927
# Epoch 4/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.5256 - categorical_accuracy: 0.8513
# Epoch 00004: val_categorical_accuracy improved from 0.89269 to 0.89916, saving model to checkpoints/best_weights0-004.hdf5
# 1930/1929 [==============================] - 221s 114ms/step - loss: 0.5260 - categorical_accuracy: 0.8513 - val_loss: 0.3545 - val_categorical_accuracy: 0.8992
# Epoch 5/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4623 - categorical_accuracy: 0.8682
# Epoch 00005: val_categorical_accuracy improved from 0.89916 to 0.90120, saving model to checkpoints/best_weights0-005.hdf5
# 1930/1929 [==============================] - 220s 114ms/step - loss: 0.4622 - categorical_accuracy: 0.8682 - val_loss: 0.3452 - val_categorical_accuracy: 0.9012
# Epoch 6/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4307 - categorical_accuracy: 0.8789
# Epoch 00006: val_categorical_accuracy did not improve from 0.90120
# 1930/1929 [==============================] - 213s 110ms/step - loss: 0.4309 - categorical_accuracy: 0.8789 - val_loss: 0.4850 - val_categorical_accuracy: 0.8667
# Epoch 7/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4047 - categorical_accuracy: 0.8861
# Epoch 00007: val_categorical_accuracy improved from 0.90120 to 0.92206, saving model to checkpoints/best_weights0-007.hdf5
# 1930/1929 [==============================] - 207s 107ms/step - loss: 0.4047 - categorical_accuracy: 0.8861 - val_loss: 0.2768 - val_categorical_accuracy: 0.9221
# Epoch 8/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3734 - categorical_accuracy: 0.8963
# Epoch 00008: val_categorical_accuracy improved from 0.92206 to 0.92974, saving model to checkpoints/best_weights0-008.hdf5
# 1930/1929 [==============================] - 199s 103ms/step - loss: 0.3732 - categorical_accuracy: 0.8963 - val_loss: 0.2537 - val_categorical_accuracy: 0.9297
# Epoch 9/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3427 - categorical_accuracy: 0.9033
# Epoch 00009: val_categorical_accuracy did not improve from 0.92974
# 1930/1929 [==============================] - 202s 105ms/step - loss: 0.3429 - categorical_accuracy: 0.9033 - val_loss: 0.3233 - val_categorical_accuracy: 0.9078
# Epoch 10/20
# 1926/1929 [============================>.] - ETA: 0s - loss: 0.3377 - categorical_accuracy: 0.9048
# Epoch 00010: val_categorical_accuracy did not improve from 0.92974
# 1930/1929 [==============================] - 199s 103ms/step - loss: 0.3377 - categorical_accuracy: 0.9047 - val_loss: 0.2542 - val_categorical_accuracy: 0.9267
# Epoch 11/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3179 - categorical_accuracy: 0.9111
# Epoch 00011: val_categorical_accuracy did not improve from 0.92974
# 1930/1929 [==============================] - 195s 101ms/step - loss: 0.3181 - categorical_accuracy: 0.9111 - val_loss: 0.2525 - val_categorical_accuracy: 0.9295
# Epoch 12/20
# 1926/1929 [============================>.] - ETA: 0s - loss: 0.3071 - categorical_accuracy: 0.9119
# Epoch 00012: val_categorical_accuracy improved from 0.92974 to 0.93705, saving model to checkpoints/best_weights0-012.hdf5
# 1930/1929 [==============================] - 201s 104ms/step - loss: 0.3082 - categorical_accuracy: 0.9118 - val_loss: 0.2147 - val_categorical_accuracy: 0.9371
# Epoch 13/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2975 - categorical_accuracy: 0.9168
# Epoch 00013: val_categorical_accuracy improved from 0.93705 to 0.93861, saving model to checkpoints/best_weights0-013.hdf5
# 1930/1929 [==============================] - 167s 87ms/step - loss: 0.2974 - categorical_accuracy: 0.9168 - val_loss: 0.2220 - val_categorical_accuracy: 0.9386
# Epoch 14/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2816 - categorical_accuracy: 0.9203
# Epoch 00014: val_categorical_accuracy improved from 0.93861 to 0.93909, saving model to checkpoints/best_weights0-014.hdf5
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.2820 - categorical_accuracy: 0.9203 - val_loss: 0.2202 - val_categorical_accuracy: 0.9391
# Epoch 15/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2786 - categorical_accuracy: 0.9230
# Epoch 00015: val_categorical_accuracy did not improve from 0.93909
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.2792 - categorical_accuracy: 0.9229 - val_loss: 0.2239 - val_categorical_accuracy: 0.9362
# Epoch 16/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2610 - categorical_accuracy: 0.9255
# Epoch 00016: val_categorical_accuracy improved from 0.93909 to 0.94089, saving model to checkpoints/best_weights0-016.hdf5
# 1930/1929 [==============================] - 167s 86ms/step - loss: 0.2609 - categorical_accuracy: 0.9255 - val_loss: 0.2063 - val_categorical_accuracy: 0.9409
# Epoch 17/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2603 - categorical_accuracy: 0.9256
# Epoch 00017: val_categorical_accuracy improved from 0.94089 to 0.94400, saving model to checkpoints/best_weights0-017.hdf5
# 1930/1929 [==============================] - 167s 86ms/step - loss: 0.2602 - categorical_accuracy: 0.9257 - val_loss: 0.1917 - val_categorical_accuracy: 0.9440
# Epoch 18/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2614 - categorical_accuracy: 0.9271
# Epoch 00018: val_categorical_accuracy improved from 0.94400 to 0.94436, saving model to checkpoints/best_weights0-018.hdf5
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.2616 - categorical_accuracy: 0.9271 - val_loss: 0.1944 - val_categorical_accuracy: 0.9444
# Epoch 19/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2463 - categorical_accuracy: 0.9301
# Epoch 00019: val_categorical_accuracy did not improve from 0.94436
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.2462 - categorical_accuracy: 0.9301 - val_loss: 0.2236 - val_categorical_accuracy: 0.9390
# Epoch 20/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2356 - categorical_accuracy: 0.9328
# Epoch 00020: val_categorical_accuracy did not improve from 0.94436
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.2355 - categorical_accuracy: 0.9328 - val_loss: 0.2184 - val_categorical_accuracy: 0.9386
# 790/790 [==============================] - 6s 8ms/step - loss: 0.0406 - categorical_accuracy: 0.9884
# [0.040618795423727566, 0.9884402]
# Train for 1929.3125 steps, validate for 521.25 steps
# Epoch 1/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 1.8477 - categorical_accuracy: 0.4770
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.77242, saving model to checkpoints/best_weights1-001.hdf5
# 1930/1929 [==============================] - 168s 87ms/step - loss: 1.8469 - categorical_accuracy: 0.4770 - val_loss: 0.7631 - val_categorical_accuracy: 0.7724
# Epoch 2/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.7482 - categorical_accuracy: 0.7793
# Epoch 00002: val_categorical_accuracy improved from 0.77242 to 0.86942, saving model to checkpoints/best_weights1-002.hdf5
# 1930/1929 [==============================] - 171s 89ms/step - loss: 0.7481 - categorical_accuracy: 0.7793 - val_loss: 0.4480 - val_categorical_accuracy: 0.8694
# Epoch 3/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.5710 - categorical_accuracy: 0.8356
# Epoch 00003: val_categorical_accuracy improved from 0.86942 to 0.89868, saving model to checkpoints/best_weights1-003.hdf5
# 1930/1929 [==============================] - 169s 88ms/step - loss: 0.5715 - categorical_accuracy: 0.8356 - val_loss: 0.3462 - val_categorical_accuracy: 0.8987
# Epoch 4/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4992 - categorical_accuracy: 0.8576
# Epoch 00004: val_categorical_accuracy improved from 0.89868 to 0.91331, saving model to checkpoints/best_weights1-004.hdf5
# 1930/1929 [==============================] - 171s 88ms/step - loss: 0.4990 - categorical_accuracy: 0.8577 - val_loss: 0.3070 - val_categorical_accuracy: 0.9133
# Epoch 5/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4355 - categorical_accuracy: 0.8732
# Epoch 00005: val_categorical_accuracy did not improve from 0.91331
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.4355 - categorical_accuracy: 0.8732 - val_loss: 0.3287 - val_categorical_accuracy: 0.9066
# Epoch 6/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4053 - categorical_accuracy: 0.8858
# Epoch 00006: val_categorical_accuracy did not improve from 0.91331
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.4058 - categorical_accuracy: 0.8858 - val_loss: 0.3628 - val_categorical_accuracy: 0.9013
# Epoch 7/20
# 1926/1929 [============================>.] - ETA: 0s - loss: 0.3877 - categorical_accuracy: 0.8907
# Epoch 00007: val_categorical_accuracy improved from 0.91331 to 0.93573, saving model to checkpoints/best_weights1-007.hdf5
# 1930/1929 [==============================] - 167s 86ms/step - loss: 0.3873 - categorical_accuracy: 0.8908 - val_loss: 0.2335 - val_categorical_accuracy: 0.9357
# Epoch 8/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3516 - categorical_accuracy: 0.9019
# Epoch 00008: val_categorical_accuracy improved from 0.93573 to 0.93993, saving model to checkpoints/best_weights1-008.hdf5
# 1930/1929 [==============================] - 164s 85ms/step - loss: 0.3514 - categorical_accuracy: 0.9019 - val_loss: 0.2164 - val_categorical_accuracy: 0.9399
# Epoch 9/20
# 1928/1929 [============================>.] - ETA: 0s - loss: 0.3393 - categorical_accuracy: 0.9050
# Epoch 00009: val_categorical_accuracy did not improve from 0.93993
# 1930/1929 [==============================] - 172s 89ms/step - loss: 0.3391 - categorical_accuracy: 0.9051 - val_loss: 0.2399 - val_categorical_accuracy: 0.9336
# Epoch 10/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3227 - categorical_accuracy: 0.9080
# Epoch 00010: val_categorical_accuracy improved from 0.93993 to 0.94137, saving model to checkpoints/best_weights1-010.hdf5
# 1930/1929 [==============================] - 172s 89ms/step - loss: 0.3230 - categorical_accuracy: 0.9080 - val_loss: 0.1990 - val_categorical_accuracy: 0.9414
# Epoch 11/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3005 - categorical_accuracy: 0.9156
# Epoch 00011: val_categorical_accuracy did not improve from 0.94137
# 1930/1929 [==============================] - 167s 86ms/step - loss: 0.3005 - categorical_accuracy: 0.9156 - val_loss: 0.2657 - val_categorical_accuracy: 0.9273
# Epoch 12/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2926 - categorical_accuracy: 0.9169
# Epoch 00012: val_categorical_accuracy did not improve from 0.94137
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.2930 - categorical_accuracy: 0.9169 - val_loss: 0.2222 - val_categorical_accuracy: 0.9351
# Epoch 13/20
# 1927/1929 [============================>.] - ETA: 0s - loss: 0.2790 - categorical_accuracy: 0.9210
# Epoch 00013: val_categorical_accuracy improved from 0.94137 to 0.94424, saving model to checkpoints/best_weights1-013.hdf5
# 1930/1929 [==============================] - 172s 89ms/step - loss: 0.2793 - categorical_accuracy: 0.9210 - val_loss: 0.1957 - val_categorical_accuracy: 0.9442
# Epoch 14/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2684 - categorical_accuracy: 0.9240
# Epoch 00014: val_categorical_accuracy improved from 0.94424 to 0.94796, saving model to checkpoints/best_weights1-014.hdf5
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.2683 - categorical_accuracy: 0.9240 - val_loss: 0.1808 - val_categorical_accuracy: 0.9480
# Epoch 15/20
# 1923/1929 [============================>.] - ETA: 0s - loss: 0.2634 - categorical_accuracy: 0.9255
# Epoch 00015: val_categorical_accuracy did not improve from 0.94796
# 1930/1929 [==============================] - 167s 87ms/step - loss: 0.2650 - categorical_accuracy: 0.9253 - val_loss: 0.2737 - val_categorical_accuracy: 0.9243
# Epoch 16/20
# 1928/1929 [============================>.] - ETA: 0s - loss: 0.2622 - categorical_accuracy: 0.9266
# Epoch 00016: val_categorical_accuracy did not improve from 0.94796
# 1930/1929 [==============================] - 167s 87ms/step - loss: 0.2622 - categorical_accuracy: 0.9266 - val_loss: 0.2158 - val_categorical_accuracy: 0.9385
# Epoch 17/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2553 - categorical_accuracy: 0.9284
# Epoch 00017: val_categorical_accuracy did not improve from 0.94796
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.2557 - categorical_accuracy: 0.9284 - val_loss: 0.1822 - val_categorical_accuracy: 0.9478
# Epoch 18/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2412 - categorical_accuracy: 0.9333
# Epoch 00018: val_categorical_accuracy did not improve from 0.94796
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.2410 - categorical_accuracy: 0.9333 - val_loss: 0.1761 - val_categorical_accuracy: 0.9471
# Epoch 19/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2451 - categorical_accuracy: 0.9311
# Epoch 00019: val_categorical_accuracy did not improve from 0.94796
# 1930/1929 [==============================] - 171s 89ms/step - loss: 0.2456 - categorical_accuracy: 0.9311 - val_loss: 0.1925 - val_categorical_accuracy: 0.9438
# Epoch 20/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2323 - categorical_accuracy: 0.9360
# Epoch 00020: val_categorical_accuracy improved from 0.94796 to 0.94856, saving model to checkpoints/best_weights1-020.hdf5
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.2322 - categorical_accuracy: 0.9361 - val_loss: 0.1795 - val_categorical_accuracy: 0.9486
# 790/790 [==============================] - 6s 8ms/step - loss: 0.0338 - categorical_accuracy: 0.9907
# [0.033751730445259503, 0.99073637]
# Train for 1929.3125 steps, validate for 521.25 steps
# Epoch 1/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 2.0797 - categorical_accuracy: 0.3972
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.70348, saving model to checkpoints/best_weights2-001.hdf5
# 1930/1929 [==============================] - 170s 88ms/step - loss: 2.0791 - categorical_accuracy: 0.3973 - val_loss: 1.0060 - val_categorical_accuracy: 0.7035
# Epoch 2/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.9829 - categorical_accuracy: 0.7093
# Epoch 00002: val_categorical_accuracy improved from 0.70348 to 0.85240, saving model to checkpoints/best_weights2-002.hdf5
# 1930/1929 [==============================] - 174s 90ms/step - loss: 0.9828 - categorical_accuracy: 0.7093 - val_loss: 0.5115 - val_categorical_accuracy: 0.8524
# Epoch 3/20
# 1922/1929 [============================>.] - ETA: 0s - loss: 0.7358 - categorical_accuracy: 0.7849
# Epoch 00003: val_categorical_accuracy improved from 0.85240 to 0.86163, saving model to checkpoints/best_weights2-003.hdf5
# 1930/1929 [==============================] - 167s 87ms/step - loss: 0.7353 - categorical_accuracy: 0.7850 - val_loss: 0.4647 - val_categorical_accuracy: 0.8616
# Epoch 4/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.6319 - categorical_accuracy: 0.8182
# Epoch 00004: val_categorical_accuracy improved from 0.86163 to 0.89544, saving model to checkpoints/best_weights2-004.hdf5
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.6316 - categorical_accuracy: 0.8183 - val_loss: 0.3748 - val_categorical_accuracy: 0.8954
# Epoch 5/20
# 1926/1929 [============================>.] - ETA: 0s - loss: 0.5627 - categorical_accuracy: 0.8402
# Epoch 00005: val_categorical_accuracy improved from 0.89544 to 0.91343, saving model to checkpoints/best_weights2-005.hdf5
# 1930/1929 [==============================] - 171s 89ms/step - loss: 0.5625 - categorical_accuracy: 0.8402 - val_loss: 0.3092 - val_categorical_accuracy: 0.9134
# Epoch 6/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4964 - categorical_accuracy: 0.8556
# Epoch 00006: val_categorical_accuracy did not improve from 0.91343
# 1930/1929 [==============================] - 164s 85ms/step - loss: 0.4970 - categorical_accuracy: 0.8556 - val_loss: 0.3059 - val_categorical_accuracy: 0.9116
# Epoch 7/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4651 - categorical_accuracy: 0.8672
# Epoch 00007: val_categorical_accuracy improved from 0.91343 to 0.91487, saving model to checkpoints/best_weights2-007.hdf5
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.4658 - categorical_accuracy: 0.8671 - val_loss: 0.3125 - val_categorical_accuracy: 0.9149
# Epoch 8/20
# 1921/1929 [============================>.] - ETA: 0s - loss: 0.4491 - categorical_accuracy: 0.8729
# Epoch 00008: val_categorical_accuracy improved from 0.91487 to 0.91763, saving model to checkpoints/best_weights2-008.hdf5
# 1930/1929 [==============================] - 164s 85ms/step - loss: 0.4493 - categorical_accuracy: 0.8728 - val_loss: 0.2988 - val_categorical_accuracy: 0.9176
# Epoch 9/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4097 - categorical_accuracy: 0.8834
# Epoch 00009: val_categorical_accuracy improved from 0.91763 to 0.92506, saving model to checkpoints/best_weights2-009.hdf5
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.4101 - categorical_accuracy: 0.8834 - val_loss: 0.2758 - val_categorical_accuracy: 0.9251
# Epoch 10/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3940 - categorical_accuracy: 0.8883 ETA:
# Epoch 00010: val_categorical_accuracy improved from 0.92506 to 0.93465, saving model to checkpoints/best_weights2-010.hdf5
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.3938 - categorical_accuracy: 0.8883 - val_loss: 0.2367 - val_categorical_accuracy: 0.9347
# Epoch 11/20
# 1924/1929 [============================>.] - ETA: 0s - loss: 0.3659 - categorical_accuracy: 0.8964
# Epoch 00011: val_categorical_accuracy did not improve from 0.93465
# 1930/1929 [==============================] - 164s 85ms/step - loss: 0.3663 - categorical_accuracy: 0.8962 - val_loss: 0.2493 - val_categorical_accuracy: 0.9331
# Epoch 12/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3572 - categorical_accuracy: 0.8988
# Epoch 00012: val_categorical_accuracy did not improve from 0.93465
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.3575 - categorical_accuracy: 0.8988 - val_loss: 0.2304 - val_categorical_accuracy: 0.9321
# Epoch 13/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3436 - categorical_accuracy: 0.9021
# Epoch 00013: val_categorical_accuracy did not improve from 0.93465
# 1930/1929 [==============================] - 164s 85ms/step - loss: 0.3447 - categorical_accuracy: 0.9021 - val_loss: 0.2541 - val_categorical_accuracy: 0.9291
# Epoch 14/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3434 - categorical_accuracy: 0.9039
# Epoch 00014: val_categorical_accuracy did not improve from 0.93465
# 1930/1929 [==============================] - 169s 88ms/step - loss: 0.3438 - categorical_accuracy: 0.9039 - val_loss: 0.2717 - val_categorical_accuracy: 0.9237
# Epoch 15/20
# 1927/1929 [============================>.] - ETA: 0s - loss: 0.3222 - categorical_accuracy: 0.9093
# Epoch 00015: val_categorical_accuracy did not improve from 0.93465
# 1930/1929 [==============================] - 167s 87ms/step - loss: 0.3225 - categorical_accuracy: 0.9093 - val_loss: 0.2839 - val_categorical_accuracy: 0.9203
# Epoch 16/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3105 - categorical_accuracy: 0.9121
# Epoch 00016: val_categorical_accuracy did not improve from 0.93465
# 1930/1929 [==============================] - 165s 86ms/step - loss: 0.3113 - categorical_accuracy: 0.9120 - val_loss: 0.2629 - val_categorical_accuracy: 0.9255
# Epoch 17/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3006 - categorical_accuracy: 0.9156
# Epoch 00017: val_categorical_accuracy improved from 0.93465 to 0.94329, saving model to checkpoints/best_weights2-017.hdf5
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.3007 - categorical_accuracy: 0.9156 - val_loss: 0.1880 - val_categorical_accuracy: 0.9433
# Epoch 18/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2901 - categorical_accuracy: 0.9184
# Epoch 00018: val_categorical_accuracy did not improve from 0.94329
# 1930/1929 [==============================] - 170s 88ms/step - loss: 0.2904 - categorical_accuracy: 0.9183 - val_loss: 0.2092 - val_categorical_accuracy: 0.9387
# Epoch 19/20
# 1928/1929 [============================>.] - ETA: 0s - loss: 0.2933 - categorical_accuracy: 0.9165
# Epoch 00019: val_categorical_accuracy improved from 0.94329 to 0.94676, saving model to checkpoints/best_weights2-019.hdf5
# 1930/1929 [==============================] - 170s 88ms/step - loss: 0.2931 - categorical_accuracy: 0.9166 - val_loss: 0.1850 - val_categorical_accuracy: 0.9468
# Epoch 20/20
# 1928/1929 [============================>.] - ETA: 0s - loss: 0.2826 - categorical_accuracy: 0.9217
# Epoch 00020: val_categorical_accuracy did not improve from 0.94676
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.2826 - categorical_accuracy: 0.9217 - val_loss: 0.2051 - val_categorical_accuracy: 0.9430
# 790/790 [==============================] - 4s 6ms/step - loss: 0.0406 - categorical_accuracy: 0.9876
# [0.04062446204486921, 0.9876484]
# Train for 1929.3125 steps, validate for 521.25 steps
# Epoch 1/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 2.2262 - categorical_accuracy: 0.3698
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.73106, saving model to checkpoints/best_weights3-001.hdf5
# 1930/1929 [==============================] - 170s 88ms/step - loss: 2.2253 - categorical_accuracy: 0.3699 - val_loss: 0.9328 - val_categorical_accuracy: 0.7311
# Epoch 2/20
# 1925/1929 [============================>.] - ETA: 0s - loss: 1.0018 - categorical_accuracy: 0.7001
# Epoch 00002: val_categorical_accuracy improved from 0.73106 to 0.79101, saving model to checkpoints/best_weights3-002.hdf5
# 1930/1929 [==============================] - 163s 85ms/step - loss: 1.0010 - categorical_accuracy: 0.7002 - val_loss: 0.7415 - val_categorical_accuracy: 0.7910
# Epoch 3/20
# 1923/1929 [============================>.] - ETA: 0s - loss: 0.7326 - categorical_accuracy: 0.7869
# Epoch 00003: val_categorical_accuracy improved from 0.79101 to 0.87146, saving model to checkpoints/best_weights3-003.hdf5
# 1930/1929 [==============================] - 167s 87ms/step - loss: 0.7327 - categorical_accuracy: 0.7868 - val_loss: 0.4236 - val_categorical_accuracy: 0.8715
# Epoch 4/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.6102 - categorical_accuracy: 0.8237
# Epoch 00004: val_categorical_accuracy improved from 0.87146 to 0.88765, saving model to checkpoints/best_weights3-004.hdf5
# 1930/1929 [==============================] - 169s 88ms/step - loss: 0.6106 - categorical_accuracy: 0.8236 - val_loss: 0.3818 - val_categorical_accuracy: 0.8876
# Epoch 5/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.5514 - categorical_accuracy: 0.8414
# Epoch 00005: val_categorical_accuracy improved from 0.88765 to 0.89904, saving model to checkpoints/best_weights3-005.hdf5
# 1930/1929 [==============================] - 174s 90ms/step - loss: 0.5519 - categorical_accuracy: 0.8414 - val_loss: 0.3455 - val_categorical_accuracy: 0.8990
# Epoch 6/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4914 - categorical_accuracy: 0.8596
# Epoch 00006: val_categorical_accuracy improved from 0.89904 to 0.89916, saving model to checkpoints/best_weights3-006.hdf5
# 1930/1929 [==============================] - 165s 85ms/step - loss: 0.4913 - categorical_accuracy: 0.8596 - val_loss: 0.3400 - val_categorical_accuracy: 0.8992
# Epoch 7/20
# 1928/1929 [============================>.] - ETA: 0s - loss: 0.4557 - categorical_accuracy: 0.8714
# Epoch 00007: val_categorical_accuracy improved from 0.89916 to 0.91091, saving model to checkpoints/best_weights3-007.hdf5
# 1930/1929 [==============================] - 165s 86ms/step - loss: 0.4562 - categorical_accuracy: 0.8714 - val_loss: 0.2956 - val_categorical_accuracy: 0.9109
# Epoch 8/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4309 - categorical_accuracy: 0.8783
# Epoch 00008: val_categorical_accuracy improved from 0.91091 to 0.91391, saving model to checkpoints/best_weights3-008.hdf5
# 1930/1929 [==============================] - 167s 87ms/step - loss: 0.4307 - categorical_accuracy: 0.8783 - val_loss: 0.3015 - val_categorical_accuracy: 0.9139
# Epoch 9/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4058 - categorical_accuracy: 0.8849
# Epoch 00009: val_categorical_accuracy improved from 0.91391 to 0.92638, saving model to checkpoints/best_weights3-009.hdf5
# 1930/1929 [==============================] - 167s 86ms/step - loss: 0.4057 - categorical_accuracy: 0.8850 - val_loss: 0.2556 - val_categorical_accuracy: 0.9264
# Epoch 10/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3678 - categorical_accuracy: 0.8952
# Epoch 00010: val_categorical_accuracy did not improve from 0.92638
# 1930/1929 [==============================] - 163s 84ms/step - loss: 0.3676 - categorical_accuracy: 0.8952 - val_loss: 0.2785 - val_categorical_accuracy: 0.9195
# Epoch 11/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3532 - categorical_accuracy: 0.8996
# Epoch 00011: val_categorical_accuracy did not improve from 0.92638
# 1930/1929 [==============================] - 165s 85ms/step - loss: 0.3543 - categorical_accuracy: 0.8996 - val_loss: 0.2607 - val_categorical_accuracy: 0.9247
# Epoch 12/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3402 - categorical_accuracy: 0.9048
# Epoch 00012: val_categorical_accuracy improved from 0.92638 to 0.93465, saving model to checkpoints/best_weights3-012.hdf5
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.3411 - categorical_accuracy: 0.9047 - val_loss: 0.2228 - val_categorical_accuracy: 0.9347
# Epoch 13/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3378 - categorical_accuracy: 0.9056
# Epoch 00013: val_categorical_accuracy improved from 0.93465 to 0.94017, saving model to checkpoints/best_weights3-013.hdf5
# 1930/1929 [==============================] - 163s 85ms/step - loss: 0.3377 - categorical_accuracy: 0.9056 - val_loss: 0.2076 - val_categorical_accuracy: 0.9402
# Epoch 14/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3181 - categorical_accuracy: 0.9099
# Epoch 00014: val_categorical_accuracy did not improve from 0.94017
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.3179 - categorical_accuracy: 0.9099 - val_loss: 0.2267 - val_categorical_accuracy: 0.9330
# Epoch 15/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3101 - categorical_accuracy: 0.9129
# Epoch 00015: val_categorical_accuracy did not improve from 0.94017
# 1930/1929 [==============================] - 163s 85ms/step - loss: 0.3100 - categorical_accuracy: 0.9129 - val_loss: 0.2900 - val_categorical_accuracy: 0.9222
# Epoch 16/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3087 - categorical_accuracy: 0.9143
# Epoch 00016: val_categorical_accuracy did not improve from 0.94017
# 1930/1929 [==============================] - 164s 85ms/step - loss: 0.3095 - categorical_accuracy: 0.9143 - val_loss: 0.2152 - val_categorical_accuracy: 0.9373
# Epoch 17/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2814 - categorical_accuracy: 0.9225
# Epoch 00017: val_categorical_accuracy improved from 0.94017 to 0.94269, saving model to checkpoints/best_weights3-017.hdf5
# 1930/1929 [==============================] - 162s 84ms/step - loss: 0.2812 - categorical_accuracy: 0.9225 - val_loss: 0.1974 - val_categorical_accuracy: 0.9427
# Epoch 18/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2767 - categorical_accuracy: 0.9224
# Epoch 00018: val_categorical_accuracy improved from 0.94269 to 0.94616, saving model to checkpoints/best_weights3-018.hdf5
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.2767 - categorical_accuracy: 0.9223 - val_loss: 0.1834 - val_categorical_accuracy: 0.9462
# Epoch 19/20
# 1921/1929 [============================>.] - ETA: 0s - loss: 0.2808 - categorical_accuracy: 0.9209
# Epoch 00019: val_categorical_accuracy did not improve from 0.94616
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.2804 - categorical_accuracy: 0.9209 - val_loss: 0.1805 - val_categorical_accuracy: 0.9462
# Epoch 20/20
# 1925/1929 [============================>.] - ETA: 0s - loss: 0.2663 - categorical_accuracy: 0.9270
# Epoch 00020: val_categorical_accuracy did not improve from 0.94616
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.2665 - categorical_accuracy: 0.9271 - val_loss: 0.1990 - val_categorical_accuracy: 0.9402
# 790/790 [==============================] - 4s 6ms/step - loss: 0.0388 - categorical_accuracy: 0.9890
# [0.038797403556607234, 0.9889945]
# Train for 1929.3125 steps, validate for 521.25 steps
# Epoch 1/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 2.1273 - categorical_accuracy: 0.4006
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.72374, saving model to checkpoints/best_weights4-001.hdf5
# 1930/1929 [==============================] - 171s 88ms/step - loss: 2.1274 - categorical_accuracy: 0.4007 - val_loss: 1.0084 - val_categorical_accuracy: 0.7237
# Epoch 2/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.8922 - categorical_accuracy: 0.7375
# Epoch 00002: val_categorical_accuracy improved from 0.72374 to 0.86595, saving model to checkpoints/best_weights4-002.hdf5
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.8923 - categorical_accuracy: 0.7375 - val_loss: 0.4635 - val_categorical_accuracy: 0.8659
# Epoch 3/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.6666 - categorical_accuracy: 0.8095
# Epoch 00003: val_categorical_accuracy improved from 0.86595 to 0.88585, saving model to checkpoints/best_weights4-003.hdf5
# 1930/1929 [==============================] - 170s 88ms/step - loss: 0.6666 - categorical_accuracy: 0.8095 - val_loss: 0.3889 - val_categorical_accuracy: 0.8859
# Epoch 4/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.5390 - categorical_accuracy: 0.8457
# Epoch 00004: val_categorical_accuracy improved from 0.88585 to 0.90120, saving model to checkpoints/best_weights4-004.hdf5
# 1930/1929 [==============================] - 162s 84ms/step - loss: 0.5390 - categorical_accuracy: 0.8457 - val_loss: 0.3315 - val_categorical_accuracy: 0.9012
# Epoch 5/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4950 - categorical_accuracy: 0.8583
# Epoch 00005: val_categorical_accuracy improved from 0.90120 to 0.91511, saving model to checkpoints/best_weights4-005.hdf5
# 1930/1929 [==============================] - 167s 86ms/step - loss: 0.4949 - categorical_accuracy: 0.8583 - val_loss: 0.2983 - val_categorical_accuracy: 0.9151
# Epoch 6/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4527 - categorical_accuracy: 0.8724
# Epoch 00006: val_categorical_accuracy improved from 0.91511 to 0.91547, saving model to checkpoints/best_weights4-006.hdf5
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.4527 - categorical_accuracy: 0.8724 - val_loss: 0.2915 - val_categorical_accuracy: 0.9155
# Epoch 7/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.4146 - categorical_accuracy: 0.8813
# Epoch 00007: val_categorical_accuracy improved from 0.91547 to 0.91643, saving model to checkpoints/best_weights4-007.hdf5
# 1930/1929 [==============================] - 167s 86ms/step - loss: 0.4152 - categorical_accuracy: 0.8812 - val_loss: 0.2883 - val_categorical_accuracy: 0.9164
# Epoch 8/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3865 - categorical_accuracy: 0.8905
# Epoch 00008: val_categorical_accuracy improved from 0.91643 to 0.92734, saving model to checkpoints/best_weights4-008.hdf5
# 1930/1929 [==============================] - 165s 86ms/step - loss: 0.3863 - categorical_accuracy: 0.8905 - val_loss: 0.2507 - val_categorical_accuracy: 0.9273
# Epoch 9/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3592 - categorical_accuracy: 0.8985
# Epoch 00009: val_categorical_accuracy improved from 0.92734 to 0.93621, saving model to checkpoints/best_weights4-009.hdf5
# 1930/1929 [==============================] - 167s 87ms/step - loss: 0.3591 - categorical_accuracy: 0.8985 - val_loss: 0.2265 - val_categorical_accuracy: 0.9362
# Epoch 10/20
# 1928/1929 [============================>.] - ETA: 0s - loss: 0.3469 - categorical_accuracy: 0.9028
# Epoch 00010: val_categorical_accuracy did not improve from 0.93621
# 1930/1929 [==============================] - 162s 84ms/step - loss: 0.3466 - categorical_accuracy: 0.9028 - val_loss: 0.2749 - val_categorical_accuracy: 0.9185
# Epoch 11/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3245 - categorical_accuracy: 0.9085
# Epoch 00011: val_categorical_accuracy did not improve from 0.93621
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.3243 - categorical_accuracy: 0.9085 - val_loss: 0.2147 - val_categorical_accuracy: 0.9357
# Epoch 12/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3147 - categorical_accuracy: 0.9102
# Epoch 00012: val_categorical_accuracy did not improve from 0.93621
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.3146 - categorical_accuracy: 0.9102 - val_loss: 0.2213 - val_categorical_accuracy: 0.9327
# Epoch 13/20
# 1922/1929 [============================>.] - ETA: 0s - loss: 0.3065 - categorical_accuracy: 0.9161
# Epoch 00013: val_categorical_accuracy did not improve from 0.93621
# 1930/1929 [==============================] - 166s 86ms/step - loss: 0.3065 - categorical_accuracy: 0.9160 - val_loss: 0.2561 - val_categorical_accuracy: 0.9271
# Epoch 14/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.3021 - categorical_accuracy: 0.9147
# Epoch 00014: val_categorical_accuracy improved from 0.93621 to 0.94400, saving model to checkpoints/best_weights4-014.hdf5
# 1930/1929 [==============================] - 165s 85ms/step - loss: 0.3019 - categorical_accuracy: 0.9147 - val_loss: 0.1973 - val_categorical_accuracy: 0.9440
# Epoch 15/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2862 - categorical_accuracy: 0.9187
# Epoch 00015: val_categorical_accuracy did not improve from 0.94400
# 1930/1929 [==============================] - 163s 85ms/step - loss: 0.2862 - categorical_accuracy: 0.9188 - val_loss: 0.2156 - val_categorical_accuracy: 0.9356
# Epoch 16/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2822 - categorical_accuracy: 0.9197
# Epoch 00016: val_categorical_accuracy did not improve from 0.94400
# 1930/1929 [==============================] - 163s 85ms/step - loss: 0.2821 - categorical_accuracy: 0.9198 - val_loss: 0.2027 - val_categorical_accuracy: 0.9418
# Epoch 17/20
# 1928/1929 [============================>.] - ETA: 0s - loss: 0.2782 - categorical_accuracy: 0.9230
# Epoch 00017: val_categorical_accuracy improved from 0.94400 to 0.94544, saving model to checkpoints/best_weights4-017.hdf5
# 1930/1929 [==============================] - 167s 86ms/step - loss: 0.2785 - categorical_accuracy: 0.9230 - val_loss: 0.1908 - val_categorical_accuracy: 0.9454
# Epoch 18/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2747 - categorical_accuracy: 0.9229
# Epoch 00018: val_categorical_accuracy did not improve from 0.94544
# 1930/1929 [==============================] - 169s 87ms/step - loss: 0.2746 - categorical_accuracy: 0.9229 - val_loss: 0.1945 - val_categorical_accuracy: 0.9446
# Epoch 19/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2573 - categorical_accuracy: 0.9270
# Epoch 00019: val_categorical_accuracy improved from 0.94544 to 0.94700, saving model to checkpoints/best_weights4-019.hdf5
# 1930/1929 [==============================] - 167s 87ms/step - loss: 0.2580 - categorical_accuracy: 0.9270 - val_loss: 0.1784 - val_categorical_accuracy: 0.9470
# Epoch 20/20
# 1929/1929 [============================>.] - ETA: 0s - loss: 0.2534 - categorical_accuracy: 0.9277
# Epoch 00020: val_categorical_accuracy did not improve from 0.94700
# 1930/1929 [==============================] - 168s 87ms/step - loss: 0.2538 - categorical_accuracy: 0.9277 - val_loss: 0.1801 - val_categorical_accuracy: 0.9470
# 790/790 [==============================] - 5s 6ms/step - loss: 0.0410 - categorical_accuracy: 0.9865
# [0.04102089521233717, 0.9864608]

# %%
media = (models[0].evaluate(testset)[1]\
 + models[1].evaluate(testset)[1]\
 + models[2].evaluate(testset)[1]\
 + models[3].evaluate(testset)[1]\
 + models[4].evaluate(testset)[1])/5
        
print(media)
# Out:
# 790/790 [==============================] - 5s 6ms/step - loss: 0.0406 - categorical_accuracy: 0.9884
# 790/790 [==============================] - 4s 6ms/step - loss: 0.0338 - categorical_accuracy: 0.9907
# 790/790 [==============================] - 4s 6ms/step - loss: 0.0406 - categorical_accuracy: 0.9876
# 790/790 [==============================] - 4s 6ms/step - loss: 0.0388 - categorical_accuracy: 0.9890
# 790/790 [==============================] - 4s 6ms/step - loss: 0.0415 - categorical_accuracy: 0.9865
# 0.9884560585021973

# %% [markdown]
# ### Plot the training history

# %%
print(history[0].history.keys())

# summarize history for accuracy
plt.plot(history[0].history['categorical_accuracy'])
plt.plot(history[0].history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history[0].history['loss'])
plt.plot(history[0].history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'categorical_accuracy', 'val_loss', 'val_categorical_accuracy'])

# %% [markdown]
# ### Evaluate the model on the test set
#
# This is the accuracy number that really matters

# %%
models[0].evaluate(testset)
models[1].evaluate(testset)
models[2].evaluate(testset)
models[3].evaluate(testset)
models[4].evaluate(testset)
# Out:
# 790/790 [==============================] - 5s 6ms/step - loss: 0.0406 - categorical_accuracy: 0.9884
# 790/790 [==============================] - 5s 6ms/step - loss: 0.0338 - categorical_accuracy: 0.9907
# 790/790 [==============================] - 4s 6ms/step - loss: 0.0406 - categorical_accuracy: 0.9876
# 790/790 [==============================] - 4s 6ms/step - loss: 0.0388 - categorical_accuracy: 0.9890
# 790/790 [==============================] - 4s 6ms/step - loss: 0.0410 - categorical_accuracy: 0.9865
# [0.04102076785355546, 0.9864608]

# %% [markdown]
# # Secção para exibir a categorização de 30 imagens pelo modelo 0

# %%
class_names = np.array(['limite 20','limite 30', 'limite 50', 'limmite 60', 'limite 70', 'limite 80', 'fim limite 80', 'limite 100', 'limite 120', 'proibição de ultrapassar', 'proibição de ultrapassar para pesados', 'cruzamento', 'via com prioridade', 'cedência de passagem', 'stop', 'trânsito proibido', 'trânsito proibido mercadorias', 'sentido proibido', 'perigo qualquer', 'curva esquerda', 'curva direita', 'curva esquerda e contracurva', 'lomba ou depressão', 'pavimento escorregadio', 'passagem estreita', 'trabalhos na via', 'sinalização luminosa', 'travessia de peões', 'crianças', 'ciclistas', 'neve', 'animais', 'fim proibição', 'obrigação direita', 'obrigação esquerda', 'obrigação frente', 'obrigação direita ou frente', 'obrigação frente ou esquerda', 'contornar pela direita', 'contornar pela esquerda', 'obrigação rotunda', 'fim proibição ultrapassagem', 'fim proibição ultrapassagem pesados'])

def plot_image(predictions_array, true_label, img):
  #predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
    
  plt.imshow(img, cmap=plt.cm.binary)
  
    
  predicted_label = np.argmax(predictions_array)
  true_label = np.argmax(true_label)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(predictions_array, true_label):
  #predictions_array, true_label = predictions_array, true_label[i]
  true_label = np.argmax(true_label)
  plt.grid(False)
  plt.xticks(range(43))
  plt.yticks([])
  thisplot = plt.bar(range(43), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 30
num_cols = 1
num_images = num_rows*num_cols
plt.figure(figsize=(8*2*2*num_cols, 2*num_rows))

selected=0
for i in testset.take(-1):
  a = models[0].predict(i)
  image,label = i
  for j in range(BATCH_SIZE):
    plt.subplot(num_rows, 2*num_cols, 2*selected+1)
    plot_image(a[j], label.numpy()[j], image.numpy()[j])
    plt.subplot(num_rows, 2*num_cols, 2*selected+2)
    plot_value_array(a[j], label.numpy()[j])
    selected = selected + 1
    if selected >= num_images:
        break
  if selected >= num_images:
    break
        
  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Secção para exibir até 30 imagens categorizadas incorretamento pelo modelo 0

# %%
class_names = np.array(['limite 20','limite 30', 'limite 50', 'limmite 60', 'limite 70', 'limite 80', 'fim limite 80', 'limite 100', 'limite 120', 'proibição de ultrapassar', 'proibição de ultrapassar para pesados', 'cruzamento', 'via com prioridade', 'cedência de passagem', 'stop', 'trânsito proibido', 'trânsito proibido mercadorias', 'sentido proibido', 'perigo qualquer', 'curva esquerda', 'curva direita', 'curva esquerda e contracurva', 'lomba ou depressão', 'pavimento escorregadio', 'passagem estreita', 'trabalhos na via', 'sinalização luminosa', 'travessia de peões', 'crianças', 'ciclistas', 'neve', 'animais', 'fim proibição', 'obrigação direita', 'obrigação esquerda', 'obrigação frente', 'obrigação direita ou frente', 'obrigação frente ou esquerda', 'contornar pela direita', 'contornar pela esquerda', 'obrigação rotunda', 'fim proibição ultrapassagem', 'fim proibição ultrapassagem pesados'])

def plot_image(predictions_array, true_label, img):
  #predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])
    
  plt.imshow(img, cmap=plt.cm.binary)
  
    
  predicted_label = np.argmax(predictions_array)
  true_label = np.argmax(true_label)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)


def plot_value_array(predictions_array, true_label):
  #predictions_array, true_label = predictions_array, true_label[i]
  true_label = np.argmax(true_label)
  plt.grid(False)
  plt.xticks(range(43))
  plt.yticks([])
  thisplot = plt.bar(range(43), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 30
num_cols = 1
num_images = num_rows*num_cols
plt.figure(figsize=(8*2*2*num_cols, 2*num_rows))
errados=0
for i in testset.take(-1):
  a = models[0].predict(i)
  image,label = i
  for j in range(BATCH_SIZE):
    if np.argmax(a[j]) != np.argmax(label.numpy()[j]):
      plt.subplot(num_rows, 2*num_cols, 2*errados+1)
      plot_image(a[j], label.numpy()[j], image.numpy()[j])
      plt.subplot(num_rows, 2*num_cols, 2*errados+2)
      plot_value_array(a[j], label.numpy()[j])
      errados = errados + 1
    if errados >= num_images:
        break
  if errados >= num_images:
    break
  
plt.tight_layout()
plt.show()
